# %% [markdown]
# # 1. Purpose
# This notebook is a testing ground for a human-robot chatbox interface. There are three primary elements to our intelligent chatbox:
#  * **Suggestions** using [Bootstrap-3 Typeahead](https://github.com/bassjobsen/Bootstrap-3-Typeahead), so that the user has a better understanding of the language the robot can understand.
#  * **Template-matching** to allow the robot to understand non-standard sentences. We're building off Tellex, Kollar and others' work on Spatial Description Clauses [1,2] to parse the natural language into our templates.
#  * **Online correction**, in which the operator tells the robot that the robot misunderstood.
#
#
# ## Template-matching model
# <img src="Chatbox Workflow.png" width="600">

# %% [markdown]
# # 2. Basic Chatbox with Autocomplete

# %%
# %%javascript
#
# requirejs(['bootstrap.min.js', 'bootstrap3-typeahead.min.js'], function(){});

# %% [markdown]
# <div classr="row" style="height:175px;">
#     <div class="col-md-12">
#         <!-- Chat Box -->
#         <div class="input-group col-md-8">
#           <input id="chatInput" type="text" data-provide="typeahead" autocomplete="off" class="form-control" placeholder="I think Roy is near the Kitchen.">
#           <span class="input-group-btn" style="width:10%;">
#             <button id="human_chat_button" class="btn btn-danger" type="button">Submit</button>
#           </span>
#         </div><!-- /input-group -->
#   </div><!-- /.col-lg-12 -->
# </div><!-- /.row -->

# %%
# %%javascript
#
# // // Remove space to scroll
# // window.onkeydown = function(e) {
# //     if(e.keyCode == 32 && e.target == document.body) {
# //         e.preventDefault();
# //         return false;
# //     }
# // };
#
# // // Remove all keyboard shortcuts
# // var cmd = IPython.keyboard_manager.command_shortcuts;
# // cmd.clear_shortcuts()
#
#
# // // Submit button
# // jQuery("#human_chat_button").unbind().click(function() {
# //     var str = jQuery.trim(jQuery("#chatInput").val()) + '.'
# //     console.log("You said: " + str);
# // });
#
# // //Typeahead
# // jQuery.get('typeahead.json', function(data){
# //         jQuery("#chatInput").typeahead({
# //             source:data,
# //             items:'5',
# //             matcher: function (item) {
# //                 var last = this.query.split(' ');
# //                 this.query = jQuery.trim(last[last.length-1]);
#
# //                 if(this.query.length) return ~item.toLowerCase().indexOf(this.query.toLowerCase());
# //             },
# //             updater: function (item) {
# //                 var input = this.$element.val().split(' ');
# //                 for (var i=0; i < input.length-1; i++){
# //                     word = input[i]
# //                     if (item.toLowerCase().indexOf(word.toLowerCase()) > -1){
# //                         item = item.replace(word + ' ','')
# //                     }
# //                 }
# //                 return this.$element.val().replace(new RegExp(this.query + '$'),'') + item + ' ';
# //             }
# //         });
# // }, 'json');

# %% [markdown]
# # 3. Conditional Random Fields
#
# Conditional Random Fields (CRFs) are a classification technique postulated by Lafferty et al. [4]. They are similar to Hidden Markov Models (HMMs) and stochastic grammars (SGs), but, unlike those two generative models (i.e. concerned with joint label-observation probability), are a discriminative model (i.e. concerned with label probability conditioned on observations). SGs and HMMs can be intractable because of their need to enumerate all possible observation sequences; this is not the case for CRFs.
#
# Other discriminative models, such as Maximum Entropy Markov Models (MEMMs), however, suffer from the label-bias problem, in which the transition probabilities leaving any one state only interact with other transitions leaving that state, rather than the global transition set. This causes a bias towards states with fewer outgoing transitions (as illustrated in [4]). CRFs don't have this problem, as Lafferty et al. states: "The critical difference between CRFs and MEMMs is that a MEMM uses per-state exponential models for the conditional probabilities of next states given the current state, while a CRF has a single exponential model for the joint probability of the entire sequence of labels given the observation sequence."
#
# In essence, we want to learn $p(\mathbf{Y} \vert \mathbf{X})$, where $\mathbf{Y}$ is a sequence of labels given to the sequence of observed values $\mathbf{X}$. Once we've trained our model, we can find the $\mathbf{Y_*}$ that maximizes $p(\mathbf{Y_*} \vert \mathbf{X_*})$, where a $*$ signifies a new sequence.
#
# By the Hammersley-Clifford theorem of random fields, the join distribution over $\mathbf{Y}$, given $\mathbf{X}$, is:
#
# $$
# p_\theta(\mathbf{y} \vert \mathbf{x}) \propto \exp\left(
# \sum_{e \in E,k} \lambda_k f_k(e,\mathbf{y}\vert_e,\mathbf{x}) +
# \sum_{v \in V,k} \mu_k g_k(v,\mathbf{y}\vert_v,\mathbf{x})
# \right)
# $$
#
# where $f_k(\cdot)$ and $g_k(\cdot)$ are *transition feature functions* and *state feature functions*, respectively, that are defined a priori, and $\lambda_k$, $\mu_k$ are parameters to be learned from training data.

# %%
from __future__ import division
# %load_ext autoreload
# %autoreload 2

# Training and test data
data = [['Roy','TARGET'],
        ['is','NULL'],
        ['moving','ACTION'],
        ['North','MODIFIER'],
        ['.','NULL'],
        ['That robot','TARGET'],
        ['is','NULL'],
        ['stopped','ACTION'],
        ['.','NULL'],
        ['Nothing','TARGET '],
        ['is','NULL'],
        ['next to','SPATIALRELATION'],
        ['the dresser','GROUNDING'],
        ['.','NULL'],
        ['I','NULL'],
        ['don\'t','POSITIVITY'],
        ['see','NULL'],
        ['anything','TARGET'],
        ['near','SPATIALRELATION'],
        ['the desk','GROUNDING'],
        ['.','NULL'],
        ['I think','NULL'],
        ['a robot','TARGET'],
        ['is','NULL'],
        ['in','SPATIALRELATION'],
        ['the kitchen','GROUNDING'],
        ['.','NULL'],
        ['Pris','TARGET'],
        ['is','NULL'],
        ['moving','ACTION'],
        ['really quickly','MODIFIER'],
        ['.','NULL'],
        ['The green one','TARGET'],
        ['is','NULL'],
        ['heading','ACTION'],
        ['over there','GROUNDING'],
        ['.','NULL'],
        ['The red guy','TARGET'],
        ['is','NULL'],
        ['spinning around','ACTION'],
        ['the table','GROUNDING'],
        ['.','NULL'],
        ['A robot\'s','TARGET'],
        ['moving','ACTION'],
        ['away from','MODIFIER'],
        ['you','GROUNDING'],
        ['.','NULL'],
        ['There\'s','NULL'],
        ['another robot','TARGET'],
        ['heading','ACTION'],
        ['towards','MODIFIER'],
        ['you','GROUNDING'],
        ['.','NULL'],
        ['He\'s ','TARGET'],
        ['running','ACTION'],
        ['away from','MODIFIER'],
        ['you','GROUNDING'],
        ['!','NULL'],
        ['He\'s','TARGET'],
        ['behind','SPATIALRELATION'],
        ['the desk','GROUNDING'],
        [',','NULL'],
        ['about to','NULL'],
        ['leave','ACTION'],
        ['the kitchen','GROUNDING'],
        ['.','NULL'],
        ['Two robots','TARGET'],
        ['are','NULL'],
        ['moving','ACTION'],
        ['away from','MODIFIER'], 
        ['each-other','GROUNDING'],
        ['.','NULL'],
        ['I','NULL'],
        ['think','NULL'],
        ['Pris','TARGET'],
        ['is trying to','NULL'],
        ['stay','ACTION'],
        ['in','SPATIALRELATION'],
        ['the kitchen','GROUNDING'],
        ['.','NULL'],
        ]

training_data = generate_fleming_test_data()
test_data = data

# Save to a file
# training_data = data[:len(data)//2]
# test_data = data[len(data)//2:]
with open('training.data','w') as file_:
    for d in training_data:
        str_ = '\t'.join(d) + '\n'
        str_ = str_.replace (" ", "_")
        file_.write(str_)
with open('test.data','w') as file_:
    for d in test_data:
        str_ = '\t'.join(d) + '\n'
        str_ = str_.replace (" ", "_")
        file_.write(str_)
        
        
import textwrap
# Create Template
def create_template(model_i=1):
    model0 = """
               # Unigram
               U00:%x[-2,0]
               U01:%x[-1,0]
               U02:%x[0,0]
               U03:%x[1,0]
               U04:%x[2,0]
               U05:%x[-1,0]/%x[0,0]
               U06:%x[0,0]/%x[1,0]
               
               # Bigram
               B"""

    model1 = """
               # Unigram
               U00:%x[-2,0]
               U01:%x[-1,0]
               U02:%x[0,0]
               U03:%x[1,0]
               U04:%x[2,0]
               U05:%x[-1,0]/%x[0,0]
               U06:%x[0,0]/%x[1,0]
                              
               # Bigram
               B"""
    models = [model0, model1]
    template = models[model_i]
  
    with open('template','w') as file_:
        file_.write(textwrap.dedent(template))
create_template()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['right of', 'SPATIALRELATION']
# ['the mars poster', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['right of', 'SPATIALRELATION']
# ['the mars poster', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['behind', 'SPATIALRELATION']
# ['the mars poster', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['behind', 'SPATIALRELATION']
# ['the mars poster', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the mars poster', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the mars poster', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['in front of', 'SPATIALRELATION']
# ['the mars poster', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['in front of', 'SPATIALRELATION']
# ['the mars poster', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['left of', 'SPATIALRELATION']
# ['the mars poster', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['left of', 'SPATIALRELATION']
# ['the mars poster', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['right of', 'SPATIALRELATION']
# ['the dining table', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['right of', 'SPATIALRELATION']
# ['the dining table', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['behind', 'SPATIALRELATION']
# ['the dining table', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['behind', 'SPATIALRELATION']
# ['the dining table', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the dining table', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the dining table', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['in front of', 'SPATIALRELATION']
# ['the dining table', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['in front of', 'SPATIALRELATION']
# ['the dining table', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['left of', 'SPATIALRELATION']
# ['the dining table', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['left of', 'SPATIALRELATION']
# ['the dining table', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['right of', 'SPATIALRELATION']
# ['the fridge', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['right of', 'SPATIALRELATION']
# ['the fridge', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['behind', 'SPATIALRELATION']
# ['the fridge', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['behind', 'SPATIALRELATION']
# ['the fridge', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the fridge', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the fridge', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['in front of', 'SPATIALRELATION']
# ['the fridge', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['in front of', 'SPATIALRELATION']
# ['the fridge', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['left of', 'SPATIALRELATION']
# ['the fridge', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['left of', 'SPATIALRELATION']
# ['the fridge', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['right of', 'SPATIALRELATION']
# ['the fern', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['right of', 'SPATIALRELATION']
# ['the fern', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['behind', 'SPATIALRELATION']
# ['the fern', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['behind', 'SPATIALRELATION']
# ['the fern', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the fern', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the fern', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['in front of', 'SPATIALRELATION']
# ['the fern', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['in front of', 'SPATIALRELATION']
# ['the fern', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['left of', 'SPATIALRELATION']
# ['the fern', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['left of', 'SPATIALRELATION']
# ['the fern', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['right of', 'SPATIALRELATION']
# ['the cassini poster', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['right of', 'SPATIALRELATION']
# ['the cassini poster', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['behind', 'SPATIALRELATION']
# ['the cassini poster', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['behind', 'SPATIALRELATION']
# ['the cassini poster', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the cassini poster', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the cassini poster', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['in front of', 'SPATIALRELATION']
# ['the cassini poster', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['in front of', 'SPATIALRELATION']
# ['the cassini poster', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['left of', 'SPATIALRELATION']
# ['the cassini poster', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['left of', 'SPATIALRELATION']
# ['the cassini poster', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['right of', 'SPATIALRELATION']
# ['the bookcase', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['right of', 'SPATIALRELATION']
# ['the bookcase', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['behind', 'SPATIALRELATION']
# ['the bookcase', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['behind', 'SPATIALRELATION']
# ['the bookcase', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the bookcase', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the bookcase', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['in front of', 'SPATIALRELATION']
# ['the bookcase', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['in front of', 'SPATIALRELATION']
# ['the bookcase', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['left of', 'SPATIALRELATION']
# ['the bookcase', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['left of', 'SPATIALRELATION']
# ['the bookcase', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['right of', 'SPATIALRELATION']
# ['the filing cabinet', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['right of', 'SPATIALRELATION']
# ['the filing cabinet', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['behind', 'SPATIALRELATION']
# ['the filing cabinet', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['behind', 'SPATIALRELATION']
# ['the filing cabinet', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the filing cabinet', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the filing cabinet', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['in front of', 'SPATIALRELATION']
# ['the filing cabinet', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['in front of', 'SPATIALRELATION']
# ['the filing cabinet', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['left of', 'SPATIALRELATION']
# ['the filing cabinet', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['left of', 'SPATIALRELATION']
# ['the filing cabinet', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['right of', 'SPATIALRELATION']
# ['the desk', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['right of', 'SPATIALRELATION']
# ['the desk', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['behind', 'SPATIALRELATION']
# ['the desk', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['behind', 'SPATIALRELATION']
# ['the desk', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the desk', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the desk', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['in front of', 'SPATIALRELATION']
# ['the desk', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['in front of', 'SPATIALRELATION']
# ['the desk', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['left of', 'SPATIALRELATION']
# ['the desk', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['left of', 'SPATIALRELATION']
# ['the desk', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['right of', 'SPATIALRELATION']
# ['the chair', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['right of', 'SPATIALRELATION']
# ['the chair', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['behind', 'SPATIALRELATION']
# ['the chair', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['behind', 'SPATIALRELATION']
# ['the chair', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the chair', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the chair', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['in front of', 'SPATIALRELATION']
# ['the chair', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['in front of', 'SPATIALRELATION']
# ['the chair', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['left of', 'SPATIALRELATION']
# ['the chair', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['left of', 'SPATIALRELATION']
# ['the chair', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['right of', 'SPATIALRELATION']
# ['the checkers table', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['right of', 'SPATIALRELATION']
# ['the checkers table', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['behind', 'SPATIALRELATION']
# ['the checkers table', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['behind', 'SPATIALRELATION']
# ['the checkers table', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the checkers table', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the checkers table', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['in front of', 'SPATIALRELATION']
# ['the checkers table', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['in front of', 'SPATIALRELATION']
# ['the checkers table', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['left of', 'SPATIALRELATION']
# ['the checkers table', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['left of', 'SPATIALRELATION']
# ['the checkers table', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['inside', 'SPATIALRELATION']
# ['the billiard room', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['inside', 'SPATIALRELATION']
# ['the billiard room', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the billiard room', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the billiard room', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['outside', 'SPATIALRELATION']
# ['the billiard room', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['outside', 'SPATIALRELATION']
# ['the billiard room', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['inside', 'SPATIALRELATION']
# ['the hallway', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['inside', 'SPATIALRELATION']
# ['the hallway', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the hallway', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the hallway', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['outside', 'SPATIALRELATION']
# ['the hallway', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['outside', 'SPATIALRELATION']
# ['the hallway', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['inside', 'SPATIALRELATION']
# ['the study', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['inside', 'SPATIALRELATION']
# ['the study', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the study', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the study', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['outside', 'SPATIALRELATION']
# ['the study', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['outside', 'SPATIALRELATION']
# ['the study', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['inside', 'SPATIALRELATION']
# ['the library', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['inside', 'SPATIALRELATION']
# ['the library', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the library', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the library', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['outside', 'SPATIALRELATION']
# ['the library', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['outside', 'SPATIALRELATION']
# ['the library', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['inside', 'SPATIALRELATION']
# ['the dining room', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['inside', 'SPATIALRELATION']
# ['the dining room', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the dining room', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the dining room', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['outside', 'SPATIALRELATION']
# ['the dining room', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['outside', 'SPATIALRELATION']
# ['the dining room', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['inside', 'SPATIALRELATION']
# ['the kitchen', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['inside', 'SPATIALRELATION']
# ['the kitchen', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the kitchen', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the kitchen', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is not', 'POSITIVITY']
# ['outside', 'SPATIALRELATION']
# ['the kitchen', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is not', 'POSITIVITY']
# ['outside', 'SPATIALRELATION']
# ['the kitchen', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['right of', 'SPATIALRELATION']
# ['the mars poster', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['right of', 'SPATIALRELATION']
# ['the mars poster', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['behind', 'SPATIALRELATION']
# ['the mars poster', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['behind', 'SPATIALRELATION']
# ['the mars poster', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the mars poster', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the mars poster', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['in front of', 'SPATIALRELATION']
# ['the mars poster', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['in front of', 'SPATIALRELATION']
# ['the mars poster', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['left of', 'SPATIALRELATION']
# ['the mars poster', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['left of', 'SPATIALRELATION']
# ['the mars poster', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['right of', 'SPATIALRELATION']
# ['the dining table', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['right of', 'SPATIALRELATION']
# ['the dining table', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['behind', 'SPATIALRELATION']
# ['the dining table', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['behind', 'SPATIALRELATION']
# ['the dining table', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the dining table', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the dining table', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['in front of', 'SPATIALRELATION']
# ['the dining table', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['in front of', 'SPATIALRELATION']
# ['the dining table', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['left of', 'SPATIALRELATION']
# ['the dining table', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['left of', 'SPATIALRELATION']
# ['the dining table', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['right of', 'SPATIALRELATION']
# ['the fridge', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['right of', 'SPATIALRELATION']
# ['the fridge', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['behind', 'SPATIALRELATION']
# ['the fridge', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['behind', 'SPATIALRELATION']
# ['the fridge', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the fridge', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the fridge', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['in front of', 'SPATIALRELATION']
# ['the fridge', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['in front of', 'SPATIALRELATION']
# ['the fridge', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['left of', 'SPATIALRELATION']
# ['the fridge', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['left of', 'SPATIALRELATION']
# ['the fridge', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['right of', 'SPATIALRELATION']
# ['the fern', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['right of', 'SPATIALRELATION']
# ['the fern', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['behind', 'SPATIALRELATION']
# ['the fern', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['behind', 'SPATIALRELATION']
# ['the fern', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the fern', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the fern', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['in front of', 'SPATIALRELATION']
# ['the fern', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['in front of', 'SPATIALRELATION']
# ['the fern', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['left of', 'SPATIALRELATION']
# ['the fern', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['left of', 'SPATIALRELATION']
# ['the fern', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['right of', 'SPATIALRELATION']
# ['the cassini poster', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['right of', 'SPATIALRELATION']
# ['the cassini poster', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['behind', 'SPATIALRELATION']
# ['the cassini poster', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['behind', 'SPATIALRELATION']
# ['the cassini poster', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the cassini poster', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the cassini poster', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['in front of', 'SPATIALRELATION']
# ['the cassini poster', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['in front of', 'SPATIALRELATION']
# ['the cassini poster', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['left of', 'SPATIALRELATION']
# ['the cassini poster', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['left of', 'SPATIALRELATION']
# ['the cassini poster', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['right of', 'SPATIALRELATION']
# ['the bookcase', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['right of', 'SPATIALRELATION']
# ['the bookcase', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['behind', 'SPATIALRELATION']
# ['the bookcase', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['behind', 'SPATIALRELATION']
# ['the bookcase', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the bookcase', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the bookcase', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['in front of', 'SPATIALRELATION']
# ['the bookcase', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['in front of', 'SPATIALRELATION']
# ['the bookcase', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['left of', 'SPATIALRELATION']
# ['the bookcase', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['left of', 'SPATIALRELATION']
# ['the bookcase', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['right of', 'SPATIALRELATION']
# ['the filing cabinet', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['right of', 'SPATIALRELATION']
# ['the filing cabinet', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['behind', 'SPATIALRELATION']
# ['the filing cabinet', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['behind', 'SPATIALRELATION']
# ['the filing cabinet', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the filing cabinet', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the filing cabinet', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['in front of', 'SPATIALRELATION']
# ['the filing cabinet', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['in front of', 'SPATIALRELATION']
# ['the filing cabinet', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['left of', 'SPATIALRELATION']
# ['the filing cabinet', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['left of', 'SPATIALRELATION']
# ['the filing cabinet', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['right of', 'SPATIALRELATION']
# ['the desk', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['right of', 'SPATIALRELATION']
# ['the desk', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['behind', 'SPATIALRELATION']
# ['the desk', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['behind', 'SPATIALRELATION']
# ['the desk', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the desk', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the desk', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['in front of', 'SPATIALRELATION']
# ['the desk', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['in front of', 'SPATIALRELATION']
# ['the desk', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['left of', 'SPATIALRELATION']
# ['the desk', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['left of', 'SPATIALRELATION']
# ['the desk', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['right of', 'SPATIALRELATION']
# ['the chair', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['right of', 'SPATIALRELATION']
# ['the chair', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['behind', 'SPATIALRELATION']
# ['the chair', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['behind', 'SPATIALRELATION']
# ['the chair', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the chair', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the chair', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['in front of', 'SPATIALRELATION']
# ['the chair', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['in front of', 'SPATIALRELATION']
# ['the chair', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['left of', 'SPATIALRELATION']
# ['the chair', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['left of', 'SPATIALRELATION']
# ['the chair', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['right of', 'SPATIALRELATION']
# ['the checkers table', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['right of', 'SPATIALRELATION']
# ['the checkers table', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['behind', 'SPATIALRELATION']
# ['the checkers table', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['behind', 'SPATIALRELATION']
# ['the checkers table', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the checkers table', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the checkers table', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['in front of', 'SPATIALRELATION']
# ['the checkers table', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['in front of', 'SPATIALRELATION']
# ['the checkers table', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['left of', 'SPATIALRELATION']
# ['the checkers table', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['left of', 'SPATIALRELATION']
# ['the checkers table', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['inside', 'SPATIALRELATION']
# ['the billiard room', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['inside', 'SPATIALRELATION']
# ['the billiard room', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the billiard room', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the billiard room', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['outside', 'SPATIALRELATION']
# ['the billiard room', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['outside', 'SPATIALRELATION']
# ['the billiard room', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['inside', 'SPATIALRELATION']
# ['the hallway', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['inside', 'SPATIALRELATION']
# ['the hallway', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the hallway', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the hallway', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['outside', 'SPATIALRELATION']
# ['the hallway', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['outside', 'SPATIALRELATION']
# ['the hallway', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['inside', 'SPATIALRELATION']
# ['the study', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['inside', 'SPATIALRELATION']
# ['the study', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the study', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the study', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['outside', 'SPATIALRELATION']
# ['the study', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['outside', 'SPATIALRELATION']
# ['the study', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['inside', 'SPATIALRELATION']
# ['the library', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['inside', 'SPATIALRELATION']
# ['the library', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the library', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the library', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['outside', 'SPATIALRELATION']
# ['the library', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['outside', 'SPATIALRELATION']
# ['the library', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['inside', 'SPATIALRELATION']
# ['the dining room', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['inside', 'SPATIALRELATION']
# ['the dining room', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the dining room', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the dining room', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['outside', 'SPATIALRELATION']
# ['the dining room', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['outside', 'SPATIALRELATION']
# ['the dining room', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['inside', 'SPATIALRELATION']
# ['the kitchen', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['inside', 'SPATIALRELATION']
# ['the kitchen', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the kitchen', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['near', 'SPATIALRELATION']
# ['the kitchen', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['nothing', 'TARGET']
# ['is', 'POSITIVITY']
# ['outside', 'SPATIALRELATION']
# ['the kitchen', 'GROUNDING']
# ['.', 'NULL']
# ['I know', 'NULL']
# ['a robot', 'TARGET']
# ['is', 'POSITIVITY']
# ['outside', 'SPATIALRELATION']
# ['the kitchen', 'GROUNDING']
# ['.', 'NULL']

# %%
# %%bash
# crf_learn template training.data trained_model
# crf_test -m trained_model -v1 test.data > output.data
# Out:
# CRF++: Yet Another CRF Tool Kit
# Copyright (C) 2005-2013 Taku Kudo, All rights reserved.
#
# reading training data:
# Done!0.00 s
#
# Number of sentences: 1
# Number of features:  1840
# Number of thread(s): 8
# Freq:                1
# eta:                 0.00010
# C:                   1.00000
# shrinking size:      20
# iter=0 terr=0.83333 serr=1.00000 act=1840 obj=2626.60267 diff=1.00000
# iter=1 terr=0.00000 serr=0.00000 act=1840 obj=1506.07657 diff=0.42661
# iter=2 terr=0.00000 serr=0.00000 act=1840 obj=28.91655 diff=0.98080
# iter=3 terr=0.00000 serr=0.00000 act=1840 obj=28.17784 diff=0.02555
# iter=4 terr=0.00000 serr=0.00000 act=1840 obj=25.28203 diff=0.10277
# iter=5 terr=0.00000 serr=0.00000 act=1840 obj=24.62768 diff=0.02588
# iter=6 terr=0.00000 serr=0.00000 act=1840 obj=24.32625 diff=0.01224
# iter=7 terr=0.00000 serr=0.00000 act=1840 obj=24.20138 diff=0.00513
# iter=8 terr=0.00000 serr=0.00000 act=1840 obj=24.05624 diff=0.00600
# iter=9 terr=0.00000 serr=0.00000 act=1840 obj=23.98645 diff=0.00290
# iter=10 terr=0.00000 serr=0.00000 act=1840 obj=23.94620 diff=0.00168
# iter=11 terr=0.00000 serr=0.00000 act=1840 obj=23.93882 diff=0.00031
# iter=12 terr=0.00000 serr=0.00000 act=1840 obj=23.93627 diff=0.00011
# iter=13 terr=0.00000 serr=0.00000 act=1840 obj=23.93614 diff=0.00001
# iter=14 terr=0.00000 serr=0.00000 act=1840 obj=23.93602 diff=0.00001
# iter=15 terr=0.00000 serr=0.00000 act=1840 obj=23.93601 diff=0.00000
#
# Done!0.09 s

# %%
import pandas as pd
from IPython.display import display, HTML

with open('output.data','r') as f:
    output = f.read()
    strings = output.split('\n')
    results = []
    for str_ in strings:
        result = str_.replace('/','\t').split('\t')
        if len(result) < 3:
            continue
        if result[-3] == result[-2]:
            result += [True]
        else:
            result += [False]
        results.append(result)
        
    
df = pd.DataFrame(results)
df.columns = ['Token','True Tag','Estimated Tag','Marginal prob.', 'Correctness']
num_correct = sum([1 for r in results if r[-1]])
print("{}% correct (excluding punctuation) with {} training examples and {} test examples"
      .format(num_correct/len(results) * 100, len(training_data), len(test_data) ))
display(df)
# Out:
# 47.5% correct with 1632 training examples and 80 test examples
#            Token         True Tag    Estimated Tag Marginal prob. Correctness
# 0            Roy           TARGET           TARGET       0.625711        True
# 1             is             NULL       POSITIVITY       0.796357       False
# 2         moving           ACTION  SPATIALRELATION       0.936527       False
# 3          North         MODIFIER        GROUNDING       0.941279       False
# 4              .             NULL             NULL       0.873178        True
# 5     That_robot           TARGET             NULL       0.386763       False
# 6             is             NULL  SPATIALRELATION       0.494632       False
# 7        stopped           ACTION        GROUNDING       0.650674       False
# 8              .             NULL             NULL       0.759815        True
# 9        Nothing          TARGET_           TARGET       0.567589       False
# 10            is             NULL       POSITIVITY       0.706742       False
# 11       next_to  SPATIALRELATION  SPATIALRELATION       0.907964        True
# 12   the_dresser        GROUNDING        GROUNDING       0.917652        True
# 13             .             NULL             NULL       0.829225        True
# 14             I             NULL             NULL       0.646201        True
# 15         don't       POSITIVITY             NULL       0.262338       False
# 16           see             NULL           TARGET       0.412557       False
# 17      anything           TARGET       POSITIVITY       0.651418       False
# 18          near  SPATIALRELATION  SPATIALRELATION       0.886373        True
# 19      the_desk        GROUNDING        GROUNDING       0.927576        True
# 20             .             NULL             NULL       0.947664        True
# 21       I_think             NULL             NULL       0.948594        True
# 22       a_robot           TARGET           TARGET       0.972959        True
# 23            is             NULL       POSITIVITY       0.979836       False
# 24            in  SPATIALRELATION  SPATIALRELATION       0.991425        True
# 25   the_kitchen        GROUNDING        GROUNDING       0.978534        True
# 26             .             NULL             NULL       0.955453        True
# 27          Pris           TARGET           TARGET       0.649915        True
# 28            is             NULL       POSITIVITY       0.754884       False
# 29        moving           ACTION  SPATIALRELATION       0.932629       False
# ..           ...              ...              ...            ...         ...
# 50       towards         MODIFIER  SPATIALRELATION       0.847398       False
# 51           you        GROUNDING        GROUNDING       0.842532        True
# 52             .             NULL             NULL       0.797334        True
# 53         He's_           TARGET             NULL       0.631878       False
# 54       running           ACTION           TARGET       0.507793       False
# 55     away_from         MODIFIER       POSITIVITY       0.392782       False
# 56           you        GROUNDING  SPATIALRELATION       0.319938       False
# 57             !             NULL        GROUNDING       0.243768       False
# 58          He's           TARGET             NULL       0.228211       False
# 59        behind  SPATIALRELATION             NULL       0.209411       False
# 60      the_desk        GROUNDING             NULL       0.268894       False
# 61             ,             NULL           TARGET       0.327220       False
# 62      about_to             NULL       POSITIVITY       0.522025       False
# 63         leave           ACTION  SPATIALRELATION       0.780762       False
# 64   the_kitchen        GROUNDING        GROUNDING       0.833961        True
# 65             .             NULL             NULL       0.841049        True
# 66    Two_robots           TARGET             NULL       0.747282       False
# 67           are             NULL           TARGET       0.734860       False
# 68        moving           ACTION       POSITIVITY       0.746247       False
# 69     away_from         MODIFIER  SPATIALRELATION       0.848639       False
# 70    each-other        GROUNDING        GROUNDING       0.842602        True
# 71             .             NULL             NULL       0.795554        True
# 72             I             NULL             NULL       0.628203        True
# 73         think             NULL           TARGET       0.493066       False
# 74          Pris           TARGET       POSITIVITY       0.372567       False
# 75  is_trying_to             NULL  SPATIALRELATION       0.274039       False
# 76          stay           ACTION       POSITIVITY       0.523878       False
# 77            in  SPATIALRELATION  SPATIALRELATION       0.787211        True
# 78   the_kitchen        GROUNDING        GROUNDING       0.841010        True
# 79             .             NULL             NULL       0.841697        True
#
# [80 rows x 5 columns]

# %% [markdown]
# ## 3.1 Dependency Parsing

# %%
import spacy.en
nlp = spacy.en.English()

# %%
from cops_and_robots.fusion.chatbox import TDC, TDC_Collection, generate_fleming_test_data
import logging
logging.getLogger().setLevel(logging.INFO)
    
true_tagged_document = list(test_data)
tagged_document = []
TDC_collection = TDC_Collection(true_tagged_document)

TDC_collection.plot_TDCs()
from IPython.display import Image
Image("TDC Graph.png")

# %% [markdown]
# ## Similarity checking

# %%
import numpy as np
templates = ['Desk','Room','front','back','right','fast']

similarities = np.zeros((6, 40))
for i, t in enumerate(templates):
    for j, result in enumerate(results):
        similarities[i,j] = nlp(unicode(t)).similarity(nlp(unicode(result[0].replace('_',' '))))

df_sims = pd.DataFrame(similarities.T)
df_sims.columns = templates
df_sims.index= [r[0].replace('_',' ') for r in results]
display(df_sims)
# Out:
#                    Desk      Room     front      back     right      fast
# the table      0.478249  0.449771  0.330164  0.320808  0.321449  0.265251
# .              0.224316  0.203004  0.233952  0.226962  0.240643  0.209855
# A robot's      0.366115  0.329261  0.210584  0.251988  0.269024  0.277048
# moving         0.198178  0.146636  0.212871  0.351911  0.245323  0.300679
# away from      0.213553  0.281124  0.138592  0.502341  0.247110  0.329630
# you            0.255878  0.168381  0.199957  0.178100  0.207744  0.192814
# .              0.224316  0.203004  0.233952  0.226962  0.240643  0.209855
# There's        0.334706  0.230202  0.213979  0.327802  0.295012  0.291097
# another robot  0.342890  0.362941  0.204585  0.208070  0.255945  0.258415
# heading        0.275079  0.248396  0.168222  0.292618  0.246466  0.152587
# towards        0.221653  0.113309  0.055580  0.126628  0.151048  0.163552
# you            0.255878  0.168381  0.199957  0.178100  0.207744  0.192814
# .              0.224316  0.203004  0.233952  0.226962  0.240643  0.209855
# He's           0.269315  0.199539  0.180641  0.207631  0.212117  0.192314
# running        0.189141  0.201449  0.225739  0.261451  0.201584  0.237972
# away from      0.213553  0.281124  0.138592  0.502341  0.247110  0.329630
# you            0.255878  0.168381  0.199957  0.178100  0.207744  0.192814
# !              0.246026  0.228627  0.185054  0.222266  0.176268  0.151738
# He's           0.269315  0.199539  0.180641  0.207631  0.212117  0.192314
# behind         0.207823  0.244058  0.211998  0.306064  0.271072  0.278269
# the desk       0.790489  0.465509  0.352361  0.362110  0.319671  0.252480
# ,              0.248449  0.242182  0.200535  0.173407  0.215080  0.172618
# about to       0.242815  0.225797  0.217642  0.279894  0.283550  0.334633
# leave          0.275998  0.197469  0.175893  0.291295  0.319254  0.238200
# the kitchen    0.458828  0.582767  0.334508  0.346368  0.283987  0.228031
# .              0.224316  0.203004  0.233952  0.226962  0.240643  0.209855
# Two robots     0.324033  0.310554  0.221797  0.228386  0.238809  0.246410
# are            0.206696  0.173382  0.104420  0.174153  0.226401  0.219666
# moving         0.198178  0.146636  0.212871  0.351911  0.245323  0.300679
# away from      0.213553  0.281124  0.138592  0.502341  0.247110  0.329630
# each-other     0.287419  0.294230  0.353445  0.257587  0.321932  0.263027
# .              0.224316  0.203004  0.233952  0.226962  0.240643  0.209855
# I              0.242403  0.160387  0.170682  0.085271  0.156121  0.196733
# think          0.246772  0.193213  0.204416  0.171612  0.207567  0.282178
# Pris           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# is trying to   0.308118  0.244173  0.203943  0.277154  0.257885  0.325012
# stay           0.294022  0.287928  0.158922  0.258477  0.190280  0.270473
# in             0.218249  0.236686  0.160671  0.229319  0.128121  0.254272
# the kitchen    0.458828  0.582767  0.334508  0.346368  0.283987  0.228031
# .              0.224316  0.203004  0.233952  0.226962  0.240643  0.209855

# %%
nl_target = nlp(u'Roy')
targets = ['Roy', 'Pris', 'Zhora', 'a robot', 'nothing']
targets = [nlp(unicode(t)) for t in targets]

similarities = np.zeros((len(targets), 1))
for i, target in enumerate(targets):
    similarities[i] = nl_target.similarity(target)

df_sims = pd.DataFrame(similarities.T)
df_sims.columns = [t.string for t in targets]
df_sims.index= ['Roy']
display(df_sims)

nl_ground = nlp(u'leafy plant')
groundings = ['Bookcase', 'Desk', 'Chair', 'Filing Cabinet','Dining Table', 'Mars Poster', 'Cassini Poster',
           'Fridge', 'Checkers Table', 'Fern']
groundings = [nlp(unicode(g.lower())) for g in groundings]

similarities = np.zeros((len(groundings), 1))
for i, grounding in enumerate(groundings):
    similarities[i] = nl_ground.similarity(grounding)

df_sims = pd.DataFrame(similarities.T)
df_sims.columns = [g.string for g in groundings]
df_sims.index= [nl_ground.string]
display(df_sims)
# Out:
#      Roy  Pris  Zhora   a robot   nothing
# Roy    1     0      0  0.348365  0.194701
#              bookcase      desk     chair  filing cabinet  dining table  \
# leafy plant  0.543582  0.306591  0.267159        0.268207      0.437532
#
#              mars poster  cassini poster    fridge  checkers table      fern
# leafy plant     0.346457        0.342815  0.506434         0.38132  0.619783

# %% [markdown]
# # 4. Spatial Description Clauses
#
# Building off the work of [3], Tellex, Kollar et. al [1,2] created Spatial Description Clauses (SDCs), which contain:
# * A **figure**, the subject of the sentence;
# * A **verb**, an action to take;
# * A **landmark**, an object in the environment;
# * A **spatial relation**, a geometric relation between the landmark and the figure.
#
# SDCs are hierarchical, but they make the approximation that hierarchy as a sequence of SDCs. To ensure model tractability, they use a [Conditional Random Field](https://en.wikipedia.org/wiki/Conditional_random_field) (CRF) to extract SDCs from the input text. The CRF labels each word in each sentence with one of four possible fields (figure, verb, landmark, spatial relation) or none. We would use our three (target, grounding, spatial relation) or none. **NOTE: what corpus would we use to train this?**
#
# Similarly, our human sensor model (call it SOC, or spatial observation clause) is based on:
# * A **target**, the agent to be found **NOTE: how should we generalize this?**;
# * A **grounding**, similar to the landmark **NOTE: should we simply call this a landmark for consistency?**;
# * A **spatial relation**, a geometric relation between the landmark and the target.
#
# Essentially, we have reduced the complexity of the statement by not including the **verb** component. There is no imperative -- there is only information.
#
# We give our robots a complete semantic map of the environment (knowing the locations and labels of all groundings, whether they be objects, areas, or themselves). The goal of the cop robot is to find the robber robots, which means we can't use a robber robot as a grounding, unless it is exactly known. **NOTE: Should we investigate non-deterministic groundings?**
#
# ## Tellex Formulation
# To find the best mapping between input and a plan, Tellex et al. uses :
#
# $$
# \DeclareMathOperator*{\argmax}{arg\,max}
# \argmax_P p(P,S, \vert O) = p(S \vert P,O) p(P \vert O)
# $$
#
# Where $P$ is the path (based on a topological roadmap), $S$ is the CRF-factorized sequence of SDCs provided by the human (i.e. list of directions from the humans factorized into landmarks, verbs, etc.), and $O$ are the detected objects. They model paths as transitions between viewpoints in the environment, $v_i$, and the directions as a list of SDCs. They assume the path is independent of the detected objects, so:
#
# \begin{align*}
# p(P,S \vert O) &\approx p(sdc_1, \dots, sdc_M \vert v_1, \dots, v_{M+1}, O)p(v_1, \dots, v_{M+1})\\
# &= \left[\sum_{i=1}^M p(sdc_i \vert v_i, v_{i+1}, O)\right] \left[\sum_{i=1}^M p(v_{i+1} \vert v_i \dots, v_1)\right] p(v_1)
# \end{align*}
#
# Where,
#
# \begin{align*}
# p(sdc_i \vert v_i, v_{i+1}, O) &= p(f_i, a_i, s_i, l_i \vert v_i, v_{i+1}, O) \\
# &\approx p(f_i \vert v_i, v_{i+1}, o_1, \dots, o_K) p(a_i \vert v_i, v_{i+1}) p(s_i \vert l_i, v_i, v_{i+1}, o_1, \dots, o_K) p(l_i \vert v_i, v_{i+1}, o_1, \dots, o_K)
# \end{align*}
#
# That is, the distribution is now factored into the four parts of an SDC, plus transition probabilities.
#
# ## Sweet Formulation
# Our model should be:
#
# $$
# \argmax_h p(h,sdc \vert o) = p(sdc \vert h, o) p(h \vert o)
# $$
#
# Where $h$ is a human sensor statement template, such as "I know Roy is in front of the chair."
#
# One major difference in the formulations is that ours doesn't maintain any notion of dynamics. Whereas their formulation required a batch estimate by parsing of a collection of SDCs, we require a single estimate generated online as each individual human statement arrives and is parsed into SDC form. This means that $h$, $o$ and $sdc$ are independent of any others from $H$, $O$ and $S$, respectively.
#
# $H$ can be generated from the known relations, targets and groundings in the environment. Note that we have removed the $P$ term because we do not couple planning with sensing. However, $O$ may be considered if we wish to influence $H$ and $S$ by the possible objects the human may be able to reference (i.e., give preference to statements tied to observations the human is able to make given the current context). **NOTE: Tellex's $O$ references the objects the robot is able to observe, but our $o$ references the objects the human is able to observe.** Alternatively, without taking the human context into account, we would consider the simpler case of $\argmax_h p(h,sdc) = p(sdc \vert h) p(h)$.
#
# Expanding the SDC term in $p(sdc \vert h, o)$, we get:
#
# $$
# p(sdc \vert h, o) = p(t,g,r \vert h, o) \approx p(t \vert h, o) p(g \vert h, o) p(r \vert h, o)
# $$
#
# Where $t$ is a target, $g$ is a grounding, and $r$ is a spatial relation. We approximate $p(t,g,r \vert h, o)$ by assuming independence between the target, grounding and relation (that is, a human would describe any target using any grounding and any spatial relation with uniform probability).
#
# Furthermore, we can decompose a human sensor statement $h$ into a target $t_h$, a grounding $g_h$, and a spatial relation $r_h$. We assume that targets are independent of groundings and spatial relation, groundings are independent of targets and spatial relations, and spatial relations are independent of targets and groundings, to reach:
#
# $$
# \begin{split}
# p(t \vert h, o) p(g \vert h, o) p(r \vert h, o) &= p(t \vert t_h, g_h, r_h, o) p(g \vert t_h, g_h, r_h, o) p(r \vert t_h, g_h, r_h, o) \\
# &\approx p(t \vert t_h, o) p(g \vert g_h, r_h, o) p(r \vert g_h, r_h, o)
# \end{split}
# $$
#
# In short, our goal is to solve the following:
#
# $$
# \argmax_h p(t \vert t_h, o) p(g \vert g_h, r_h, o) p(r \vert g_h, r_h, o) p(t_h, g_h, r_h \vert o)
# $$
#
# Where we use word2vec to get the co-occurrence of $t$ and $t_h$ (similarly for $g$ and $r$). If these measures are independent of the human's observation space and the joint probability of $p(t_h, g_h, r_h)$ is assumed to be uniform, then we solve the simpler problem of:
#
# $$
# \argmax_h p(t \vert t_h) p(g \vert g_h) p(r \vert r_h) = p(w_{O,t} \vert w_{I,t}) p(w_{O,g} \vert w_{I,g}) p(w_{O,r} \vert w_{I,r})
# $$
#
# Where $p(w_{O,t} \vert w_{I,t})$ takes the form following equation (2) in [3] as a measure of similarity between input and output words. However, if we include the human observation space, we know that $p(t \vert h, o) = \frac{p(t \vert h) p(t \vert o)}{p(t_h)}$ (following the derivation below). We can conceivably define $p(t \vert o)$ based on human data and we assume that $p(t_h)$ is uniform.
#
# $$
# \begin{split}
# p(t \vert t_h, o) &= \frac{p(t, t_h, o)}{p(t_h, o)} \\
# &= \frac{p(t, t_h, o)}{p(h) p(o)}\\
# &= \frac{p(t, t_h \vert o) p(o)}{p(t_h) p(o)} \\
# &= \frac{p(t_h \vert t, o) p(t \vert o)}{p(t_h)} \\
# &= \frac{p(t_h \vert t) p(t \vert o)}{p(t_h)} \\
# \end{split}
# $$
#
# ### Issues
# * We must learn the probability of specifying a non-template target, grounding or spatial relation given the observation space -- $p(t \vert o)$, $p(g \vert o)$, and $p(r \vert o)$. Since $T > T_H$ (that is, the number of ways a human could describe the target is greater than the number of specified template names for the target), we are likely to encounter terminology for which we have not learned $p(t \vert o)$, $p(g \vert o)$, and $p(r \vert o)$.
# * The word2vec-provided values $p(t_h \vert t)$, $p(g_h \vert g)$, and $p(r_h \vert r)$ are dependent on the corpus from which the neural net is trained. Corpus selection, thus, heavily influences the responses understood by the system.
#
# ### Benefits
# * Instead of simply taking $\argmax_h p(t \vert t_h) p(g \vert g_h) p(r \vert r_h)$, we can take  $J = \max_h p(t \vert t_h) p(g \vert g_h) p(r \vert r_h)$ and compare $J$ to a tunable threshold value to determine whether the robot believes it fully understands what the human is asking.
#
# ## General Assumptions
# * correctness metric based on the question: did the robot correctly rephrase the intended human statement?
# * the robot has a known semantic map of the environment, with objects and areas privately labeled.
# * temporal information - "is going to move north" vs "is moving north"

# %% [markdown]
# # 5. Word2Vec

# %% [markdown]
# # 6. References
#
# [1] T. Kollar, S. Tellex, D. Roy, and N. Roy, “Toward understanding natural language directions,” Proceeding 5th ACM/IEEE Int. Conf. Human-robot Interact. - HRI ’10, p. 259, 2010.
#
# [2] S. Tellex, T. Kollar, and S. Dickerson, “Understanding Natural Language Commands for Robotic Navigation and Mobile Manipulation.,” in AAAI Conference on Artificial Intelligence, 2011, pp. 1507–1514.
#
# [3] T. Mikolov, K. Chen, G. Corrado, and J. Dean, “Distributed Representations of Words and Phrases and their Compositionality,” Nips, pp. 1–9, 2013.
#
# [4] J. Lafferty, A. McCallum, and F. C. N. Pereira, “Conditional random fields: Probabilistic models for segmenting and labeling sequence data,” ICML ’01 Proc. Eighteenth Int. Conf. Mach. Learn., vol. 8, no. June, pp. 282–289, 2001.
#
# [5] B. Landau and R. Jackendoff, “‘What’ and ‘Where’ in Spatial Language and Spatial Cognition,” Behav. Brain Sci., vol. 16, pp. 217–265, 1993.
#
# [6] T. Kaupp, A. Makarenko, F. Ramos, B. Upcroft, S. Williams, and H. Durrant-Whyte, “Adaptive human sensor model in sensor networks,” 2005 7th Int. Conf. Inf. Fusion, FUSION, vol. 1, pp. 748–755, 2005.

# %% [markdown]
# # 7. Notes
# * Chatbox interface options:
#   * Post-hoc correction (i.e. "was this correct? yes/no")
#   * Suggestions
# * Identify confidence of translation
# * Calibration
# * Identify differences between chat and speech
#   * Spelling/typos (include autocorrection?)
#   * Abbreviations
# * Look into categorizing observations in the same way that Tellex et al. categorized imperative commands
#   * Is there a specific clause that captures all observations in the same way that an imperative clause captures all commands?
# * Develop human trials - provide recordings of the system in action to viewers, have them describe what's happening in their own words
#   * Instead of asking humans to fit a specific structure, discover how humans want to provide information
# * Discuss with Martha Palmer? Is there a taxonomy for how people provide observations?
# * Should be able to handle *distances* as well - i.e. "The table is about 30 feet past the fridge."
# * Requires a knowledge of the human state. The meaning of "behind a ball" changes based on the observer's location and the robot's location. Is it behind the ball from the robot's perspective, or from the human's? Should both be accounted for?
# * Can the chatbox suggest words that make the human a better sensor? Instead of highlighting boxes in images, have suggestions that guide a human's sensor sentences?
#  * Need a model of the human
# * What about context shifting?
# * How do you learn the cost? Esp. for
# * Should we word2vec before templating?
# * Explain the reasoning for the architecture (why not learn template words along with template categories?)
# * How do I go about with feature selection? What makes my template correct?
# * Create confusion matrix
#
# ## 7.1 Major Tasks
# 1. Review SDC and spatial language literature (Tellex, Kollar, Skubic, Jackendoff, Brugmann, Kaupp, Durrant-Whyte, Frost, Lafferty, etc.)
# 2. Develop chatbox with autocomplete
#  1. Basic, flat autocomplete
#  2. Context-relative autocomplete (e.g. weight subjects before verbs at beginning of sentence)
# 3. Develop SDC model to find most likely human sensor statement given a the tokenized and labeled input statement
#  1. Develop CRF-based labeler for input tokens (target, grounding, relation or none)
#  2. Develop segmentation algorithm to create three-term SDCs (target, grounding, relation)
#  3. Develop matching algorithm to match SDC components to template components
#  4. Develop threshhold metrics to tell the human when the robot couldn't find good enough matches.
# 4. Gather training data for SDC model
#  1. Gather training data for SDC model

# %% [markdown]
# # 8. Annotated Bibliography
#
# [1] T. Kollar, S. Tellex, D. Roy, and N. Roy, “Toward understanding natural language directions,” Proceeding 5th ACM/IEEE Int. Conf. Human-robot Interact. - HRI ’10, p. 259, 2010.
#
# [2] S. Tellex, T. Kollar, and S. Dickerson, “Understanding Natural Language Commands for Robotic Navigation and Mobile Manipulation.,” in AAAI Conference on Artificial Intelligence, 2011, pp. 1507–1514.
#
# [3] B. Landau and R. Jackendoff, “‘What’ and ‘Where’ in Spatial Language and Spatial Cognition,” Behav. Brain Sci., vol. 16, pp. 217–265, 1993.
#
# [4] T. Kaupp, A. Makarenko, F. Ramos, B. Upcroft, S. Williams, and H. Durrant-Whyte, “Adaptive human sensor model in sensor networks,” 2005 7th Int. Conf. Inf. Fusion, FUSION, vol. 1, pp. 748–755, 2005.
#
# [5] C. Matuszek, D. Fox, and K. Koscher, “Following Directions Using Statistical Machine Translation,” in IEEE International Conference on Human-Robot Interaction, 2010.
#
# [6] C. Matuszek, N. Fitzgerald, L. Zettlemoyer, L. Bo, and D. Fox, “A Joint Model of Language and Perception for Grounded Attribute Learning,” in International Conference on Machine Learning, 2012.
#
# [7] S. Lauria, G. Bugmann, T. Kyriacou, and E. Klein, “Mobile Robot Programming Using Natural Language.,” Rob. Auton. Syst., vol. 38, pp. 171–181, 2002.
#
# [8] L. S. Lopes and A. Teixeira, “Human-robot interaction through spoken language dialogue,” Proceedings. 2000 IEEE/RSJ Int. Conf. Intell. Robot. Syst. (IROS 2000) (Cat. No.00CH37113), vol. 1, pp. 528–534, 2000.
#
# [9] M. Scheutz, N. Dame, P. Schermerhorn, N. Dame, and J. Kramer, “The Utility of Affect Expression in Natural Language Interactions in Joint Human-Robot Tasks,” pp. 226–233, 2006.
#
# [10] M. Palmer, D. Gildea, and P. Kingsbury, “The Proposition Bank: An Annotated Corpus of Semantic Roles,” Comput. Linguist., vol. 31, no. 1, pp. 71–106, 2005.
#
# [11] J. Lafferty, A. McCallum, and F. C. N. Pereira, “Conditional random fields: Probabilistic models for segmenting and labeling sequence data,” ICML ’01 Proc. Eighteenth Int. Conf. Mach. Learn., vol. 8, no. June, pp. 282–289, 2001.
